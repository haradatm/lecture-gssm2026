# %% [markdown]
# # day 2

# %% [markdown]
# このノートブックの実行例は[こちら(HTML版)](https://github.com/haradatm/lecture-gssm2025/blob/main/notebooks-samples/day-2.html.zip)で確認できます

# %% [markdown]
# ---

# %% [markdown]
# ## 0. 準備

# %% [markdown]
# ### 0.1 必要なパッケージのインストール

# %%
# %%capture
# !sudo apt-get update
# !sudo apt-get install -y automake autoconf perl libtool graphviz libgraphviz-dev
# !pip install -U japanize_matplotlib pyvis pygraphviz mca

# %% [markdown]
# 教材のダウンロード

# %%
# !git clone https://github.com/haradatm/lecture-gssm2026

# %% [markdown]
# ### 0.2 MeCab インストール (時間目安: 約3分)

# %%
# %%time
# !bash lecture-gssm2026/scripts/install_mecab.sh >> install_mecab.log 2>&1
# !tail -n 1 install_mecab.log

# %% [markdown]
# ### 0.3 CaboCha インストール (時間目安: 約4分)

# %%
# %%time
# !bash lecture-gssm2026/scripts/install_cabocha.sh >> install_cabocha.log 2>&1
# !tail -n 1 install_cabocha.log

# %% [markdown]
# Python >= 3.12 対応

# %%
# !cp -f lecture-gssm2026/scripts/patch/mecab/mecab/python/MeCab.py tools/src/mecab/mecab/python/.
# !cp -f lecture-gssm2026/scripts/patch/cabocha-0.69/python/CaboCha.py tools/src/cabocha-0.69/python/.

# %% [markdown]
# ### 0.4 セッションの再起動

# %%
import os, time
time.sleep(10)  # 10秒スリープ
os.kill(os.getpid(), 9)

# %% [markdown]
# セッションの再起動後は,以下のセルから実行してください. **注意: これより前のセルを再度実行する必要はありません!**

# %% [markdown]
# ---

# %% [markdown]
# ### 0.5 動作確認

# %%
import MeCab
tagger = MeCab.Tagger("-r ./tools/usr/local/etc/mecabrc")
print(tagger.parse("今日はいい天気です"))

# %%
import CaboCha
cp = CaboCha.Parser("-r ./tools/usr/local/etc/cabocharc")
tree = cp.parse("今日はいい天気です")
print(tree.toString(CaboCha.FORMAT_LATTICE))

# %% [markdown]
# ---

# %% [markdown]
# ## 1. テキスト解析 (1)

# %%
# %load_ext autoreload
# %autoreload 2

import os
import random
import numpy as np

# 再現性のために乱数を固定する
seed = 42
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
random.seed(seed)

# %% [markdown]
# ### 1.1 形態素解析

# %% [markdown]
# (1) そのまま実行する

# %%
import MeCab
tagger = MeCab.Tagger("-r ./tools/usr/local/etc/mecabrc")
print(tagger.parse("今日はいい天気です"))

# %% [markdown]
# (2) 扱いやすいように Pandas の DataFrame に格納する

# %%
import pandas as pd

node = tagger.parseToNode("今日はいい天気です")
features = []
while node:
    features.append(node.feature.split(','))
    node = node.next

columns = [
    "品詞",
    "品詞細分類1",
    "品詞細分類2",
    "品詞細分類3",
    "活用型",
    "活用形",
    "基本形",
    "読み",
    "発音",
]
pd.DataFrame(features, columns=columns)

# %% [markdown]
# ### 1.2 係り受け解析

# %% [markdown]
# (1) そのまま実行する

# %%
import CaboCha
cp = CaboCha.Parser("-r ./tools/usr/local/etc/cabocharc")
tree = cp.parse("今日はいい天気です")
print(tree.toString(CaboCha.FORMAT_LATTICE))

# %% [markdown]
# (2) ツリー形式で出力する

# %%
print(cp.parseToString("今日はいい天気です"))

# %% [markdown]
# (3) 係り受けペアを出力する

# %%
# 構文木(tree)からチャンクを取り出す
def get_chunks(tree):
    chunks = {}
    key = 0
    for i in range(tree.size()):
        tok = tree.token(i)
        if tok.chunk:
            chunks[key] = tok.chunk
            key += 1
    return chunks


# チャンク(chunk)から表層形を取り出す
def get_surface(chunk):
    surface = ""
    beg = chunk.token_pos
    end = chunk.token_pos + chunk.token_size
    for i in range(beg, end):
        token = tree.token(i)
        surface += token.surface
    return surface

# %%
tree = cp.parse("今日はいい天気です")
chunks = get_chunks(tree)

for from_chunk in chunks.values():
    if from_chunk.link < 0:
        continue
    to_chunk = chunks[from_chunk.link]

    from_surface = get_surface(from_chunk)
    to_surface = get_surface(to_chunk)

    print(from_surface, '->', to_surface)

# %% [markdown]
# ### 1.3 辞書追加

# %% [markdown]
# (1) 辞書追加前に MeCab の解析結果を確認する

# %%
import MeCab

tagger = MeCab.Tagger("-r ./tools/usr/local/etc/mecabrc")
print(tagger.parse("この泉質は極上です"))
print(tagger.parse("この海鮮丼は美味しいです"))
print(tagger.parse("近くにスカイツリーがあります"))
print(tagger.parse("浴室にバスタオルがありません"))

# %% [markdown]
# (2) 辞書追加前に CaboCha の解析結果を確認する

# %%
import CaboCha

cp = CaboCha.Parser("-r ./tools/usr/local/etc/cabocharc")
print(cp.parse("この泉質は極上です").toString(CaboCha.FORMAT_LATTICE))
print(cp.parse("この海鮮丼は美味しいです").toString(CaboCha.FORMAT_LATTICE))
print(cp.parse("近くにスカイツリーがあります").toString(CaboCha.FORMAT_LATTICE))
print(cp.parse("浴室にバスタオルがありません").toString(CaboCha.FORMAT_LATTICE))

# %% [markdown]
# (3) 追加したい形態素の情報を CSV ファイル(user_dic.csv)に追記する

# %%
# !echo '"泉質",-1,-1,1,名詞,一般,*,*,*,*,泉質,センシツ,センシツ,USER"' >> ./tools/usr/local/lib/mecab/dic/ipadic/user_dic.csv
# !echo '"海鮮丼",-1,-1,1,名詞,一般,*,*,*,*,海鮮丼,カイセンドン,カイセンドン,USER"' >> ./tools/usr/local/lib/mecab/dic/ipadic/user_dic.csv
# !echo '"スカイツリー",-1,-1,1,名詞,一般,*,*,*,*,スカイツリー,スカイツリー,スカイツリー,USER"' >> ./tools/usr/local/lib/mecab/dic/ipadic/user_dic.csv
# !echo '"バスタオル",-1,-1,1,名詞,一般,*,*,*,*,バスタオル,バスタオル,バスタオル,USER"' >> ./tools/usr/local/lib/mecab/dic/ipadic/user_dic.csv
# !cat ./tools/usr/local/lib/mecab/dic/ipadic/user_dic.csv

# %% [markdown]
# (4) CSVファイル(user_dic.csv)をコンパイルして辞書(user.dic)を作成する

# %%
# !./tools/usr/local/libexec/mecab/mecab-dict-index \
-d ./tools/usr/local/lib/mecab/dic/ipadic \
-u ./tools/usr/local/lib/mecab/dic/ipadic/user.dic \
-f utf-8 -t utf-8 \
./tools/usr/local/lib/mecab/dic/ipadic/user_dic.csv

# %% [markdown]
# (5) 辞書追加後に MeCab の解析結果を確認する

# %%
import MeCab

tagger = MeCab.Tagger("-r ./tools/usr/local/etc/mecabrc")
print(tagger.parse("この泉質は極上です"))
print(tagger.parse("この海鮮丼は美味しいです"))
print(tagger.parse("近くにスカイツリーがあります"))
print(tagger.parse("浴室にバスタオルがありません"))

# %% [markdown]
# (6) 辞書追加後に CaboCha の解析結果を確認する

# %%
import CaboCha

cp = CaboCha.Parser("-r ./tools/usr/local/etc/cabocharc")
print(cp.parse("この泉質は極上です").toString(CaboCha.FORMAT_LATTICE))
print(cp.parse("この海鮮丼は美味しいです").toString(CaboCha.FORMAT_LATTICE))
print(cp.parse("近くにスカイツリーがあります").toString(CaboCha.FORMAT_LATTICE))
print(cp.parse("浴室にバスタオルがありません").toString(CaboCha.FORMAT_LATTICE))

# %% [markdown]
# ---

# %% [markdown]
# ## Appendix. データ理解 (Python の場合)

# %% [markdown]
# ### A.1 データのダウンロード

# %% [markdown]
# 以下のデータをダウンロードします

# %% [markdown]
# | ファイル名 | 件数 | データセット | 備考 |
# | --- | --- | --- | --- |
# | rakuten-1000-2025-2026.xlsx.zip | 10,000 | •レジャー+ビジネスの 10エリア<br>•エリアごと 1,000件 (ランダムサンプリング)<br>•期間: 2025/1~2026 GW明け | 本講義の全体を通して使用する |

# %%
# rakuten-1000-2025-2026.xlsx.zip をダウンロードする
FILE_ID = "1zBPVxWKuWYaC5zNO_q6xaVOwkCASDrpo"
# !gdown {FILE_ID}
# !unzip -o rakuten-1000-2025-2026.xlsx.zip

# %% [markdown]
# ### A.2 データの読み込み (DataFrame型)

# %%
import numpy as np
import pandas as pd

df = pd.read_excel("rakuten-1000-2025-2026.xlsx")
print(df.shape)
display(df.head())

# %% [markdown]
# 年齢と性別がブランクの場合に文字列 `na` を埋める

# %%
df['年齢'] = df['年齢'].fillna('na')
df['性別'] = df['性別'].fillna('na')

# %% [markdown]
# ### A.3 集計

# %% [markdown]
# #### (1) エリア別の件数を表示する

# %%
display(df.pivot_table(index=['カテゴリー','エリア'], columns=None, values='施設番号', aggfunc='count'))

# %% [markdown]
# サンプリングデータなので、すべて1000件になっていることを確認する

# %% [markdown]
# #### (2) 投稿者の傾向 (年代別x性別、全体で100%)

# %%
cross_df = pd.crosstab(df['年齢'], df['性別'], margins=True, margins_name='合計', normalize=True) * 100
display(cross_df.loc[:,['男性','女性','na','合計']].style.format('{:.2f}%').bar(axis=None, vmin=0, width=90, height=90, align='left'))

# %% [markdown]
# `na` を除いて表示する

# %%
cross_df = pd.crosstab(df['年齢'], df['性別'], margins=False, normalize=True) * 100
display(cross_df.loc[cross_df.index!='na',['男性','女性']].style.format('{:.2f}%').bar(axis=None, vmin=0, width=90, height=90, align='left'))

# %% [markdown]
# #### (3) 投稿者の傾向 (性別xカテゴリ別、列ごとで100%)

# %%
cross_df = pd.crosstab(df['性別'], df['カテゴリー'], margins=True, margins_name='合計', normalize='columns') * 100
display(cross_df.loc[['男性','女性','na'],:].style.format('{:.2f}%').bar(axis=None, width=90, height=90, align='left'))

# %% [markdown]
# `na` を除いて表示する

# %%
cross_df = pd.crosstab(df['性別'], df['カテゴリー'], margins=False, normalize='columns') * 100
display(cross_df.loc[['男性','女性'],:].style.format('{:.2f}%').bar(axis=None, vmin=0, width=90, height=90, align='left'))

# %% [markdown]
# #### (4) 投稿者の傾向 (性別xエリア別、列ごとで100%)

# %%
cross_df = pd.crosstab(df['性別'], [df['カテゴリー'],df['エリア']], margins=True, margins_name='合計', normalize='columns') * 100
display(cross_df.loc[['男性','女性','na'],:].style.format('{:.2f}%'))

# %% [markdown]
# カラーバーにすると横に長くなるため、ヒートマップでプロットする

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import japanize_matplotlib

plt.figure(figsize=(10,3))
sns.heatmap(cross_df.loc[['男性','女性','na'],:], annot=True, fmt='.2f', cmap='Blues')
plt.show()

# %% [markdown]
# `na` を除いてプロットする

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import japanize_matplotlib

plt.figure(figsize=(10,2))
sns.heatmap(cross_df.loc[['男性','女性'],:], annot=True, fmt='.2f', cmap='Blues')
plt.show()

# %% [markdown]
# #### (5) 投稿者の傾向 (年代xエリア別、列ごとで100%)

# %%
cross_df = pd.crosstab(df['年齢'], [df['カテゴリー'],df['エリア']], margins=True, margins_name='合計', normalize='columns') * 100
display(cross_df.style.format('{:.2f}%'))

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import japanize_matplotlib

plt.figure(figsize=(10,3))
sns.heatmap(cross_df, annot=True, fmt='.2f', cmap='Blues')
plt.show()

# %% [markdown]
# `na` を除いてプロットする

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import japanize_matplotlib

plt.figure(figsize=(10,3))
sns.heatmap(cross_df.loc[cross_df.index!='na',:], annot=True, fmt='.2f', cmap='Blues')
plt.show()

# %% [markdown]
# #### (6) 投稿者の傾向 (同伴者別xエリア別、列ごとで100%)

# %%
cross_df = pd.crosstab(df['同行者'], [df['カテゴリー'],df['エリア']], margins=True, margins_name='合計', normalize='columns') * 100
display(cross_df.loc[['一人','家族','恋人','友達','仕事仲間','その他'],:].style.format('{:.2f}%'))

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import japanize_matplotlib

plt.figure(figsize=(10,3))
sns.heatmap(cross_df.loc[['一人','家族','恋人','友達','仕事仲間','その他'],:], annot=True, fmt='.2f', cmap='Blues')
plt.show()

# %% [markdown]
# #### (7) 数値評価の構成 (部屋xカテゴリ-エリア別、列ごとに100%)

# %%
cross_df = pd.crosstab(df['部屋'], [df['カテゴリー'],df['エリア']], margins=True, margins_name='合計', normalize='columns') * 100
display(cross_df.loc[[5,4,3,2,1],:].style.format('{:.2f}%'))

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import japanize_matplotlib

plt.figure(figsize=(10,3))
sns.heatmap(cross_df.loc[[5,4,3,2,1],:], annot=True, fmt='.2f', cmap='Blues')
plt.show()

# %% [markdown]
# #### (8) 数値評価の平均 (カテゴリ-エリア別x数値評価別)

# %% [markdown]
# カテゴリ別

# %%
pivot_df = df.pivot_table(index=['カテゴリー','エリア'], values=['部屋','接客・サービス','ロケーション','朝食','夕食','温泉・お風呂','設備','清潔さ'], margins=False, aggfunc='mean', dropna=True)
display(pivot_df.loc[:,['部屋','接客・サービス','ロケーション','朝食','夕食','温泉・お風呂','設備','清潔さ']].style.format('{:.2f}').background_gradient(axis=None))

# %% [markdown]
# エリア別

# %%
pivot_df = df.pivot_table(index=['カテゴリー'], values=['部屋','接客・サービス','ロケーション','朝食','夕食','温泉・お風呂','設備','清潔さ'], margins=False, aggfunc='mean', dropna=True)
display(pivot_df.loc[:,['部屋','接客・サービス','ロケーション','朝食','夕食','温泉・お風呂','設備','清潔さ']].style.format('{:.2f}').background_gradient(axis=None))

# %% [markdown]
# #### (9)数値評価の平均 (年代x性別)

# %% [markdown]
# 20~30代

# %%
pivot_df = df[df['年齢'].isin(['20代','30代'])].pivot_table(index=['カテゴリー','性別'], values=['部屋','接客・サービス','ロケーション','朝食','夕食','温泉・お風呂','設備','清潔さ'], margins=False, aggfunc='mean', dropna=True)
display(pivot_df.loc[(['A_レジャー','B_ビジネス'],['男性','女性']),['部屋','接客・サービス','ロケーション','朝食','夕食','温泉・お風呂','設備','清潔さ']].style.format('{:.2f}').background_gradient(axis=None))

# %% [markdown]
# 40~50代

# %%
pivot_df = df[df['年齢'].isin(['40代','50代'])].pivot_table(index=['カテゴリー','性別'], values=['部屋','接客・サービス','ロケーション','朝食','夕食','温泉・お風呂','設備','清潔さ'], margins=False, aggfunc='mean', dropna=True)
display(pivot_df.loc[(['A_レジャー','B_ビジネス'],['男性','女性']),['部屋','接客・サービス','ロケーション','朝食','夕食','温泉・お風呂','設備','清潔さ']].style.format('{:.2f}').background_gradient(axis=None))

# %% [markdown]
# 60~80代

# %%
pivot_df = df[df['年齢'].isin(['60代','70代','80代'])].pivot_table(index=['カテゴリー','性別'], values=['部屋','接客・サービス','ロケーション','朝食','夕食','温泉・お風呂','設備','清潔さ'], margins=False, aggfunc='mean', dropna=True)
display(pivot_df.loc[(['A_レジャー','B_ビジネス'],['男性','女性']),['部屋','接客・サービス','ロケーション','朝食','夕食','温泉・お風呂','設備','清潔さ']].style.format('{:.2f}').background_gradient(axis=None))
